# %%
url = 'https://www.googleapis.com/youtube/v3/videos?id=mXkbWKr5ovU&key=AIzaSyC3EsHgVkGg11WfvEgVYuamubsGsjq1n-I&part=snippet,statistics'
url
# Out:
# 'https://www.googleapis.com/youtube/v3/videos?id=mXkbWKr5ovU&key=AIzaSyC3EsHgVkGg11WfvEgVYuamubsGsjq1n-I&part=snippet,statistics'

# %%
import requests
import json

r = requests.get(url=url)
data = r.json()
data
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'dyrfAmoQr_7OujyVWW8t5-kBXtk',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'iGbV7_8ZyM2pLlie6YWVWCQIlXA',
#    'id': 'mXkbWKr5ovU',
#    'snippet': {'publishedAt': '2011-05-22T19:40:14Z',
#     'channelId': 'UCq-Fj5jknLsUf-MWSy4_brA',
#     'title': 'Tumse Milke Dilka Jo Haal [Full Song] | Main Hoon Na | Shahrukh Khan',
#     'description': 'Subscribe our channel http://www.youtube.com/tseries\nLike us: http://www.facebook.com/tseriesmusic\nFollow us: http://www.twitter.com/_Tseries\n\n\nSong : Tumse Milke Dilka Jo Haal\nAlbum : Main Hoon Na\nStar cast : Shahrukh Khan, Zayed Khan\nSinger : Sonu Nigam, Altaf Sabri, Hashim Sabri \nMusic Director : Anu Malik\nLyricst : Javed Akhtar\nMusic Label : T-Series',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mXkbWKr5ovU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mXkbWKr5ovU/mqdefault.jpg',
# ...

# %%
data.keys()
# Out:
# dict_keys(['kind', 'etag', 'items', 'pageInfo'])

# %%
item = data['items']
item
# Out:
# [{'kind': 'youtube#video',
#   'etag': 'iGbV7_8ZyM2pLlie6YWVWCQIlXA',
#   'id': 'mXkbWKr5ovU',
#   'snippet': {'publishedAt': '2011-05-22T19:40:14Z',
#    'channelId': 'UCq-Fj5jknLsUf-MWSy4_brA',
#    'title': 'Tumse Milke Dilka Jo Haal [Full Song] | Main Hoon Na | Shahrukh Khan',
#    'description': 'Subscribe our channel http://www.youtube.com/tseries\nLike us: http://www.facebook.com/tseriesmusic\nFollow us: http://www.twitter.com/_Tseries\n\n\nSong : Tumse Milke Dilka Jo Haal\nAlbum : Main Hoon Na\nStar cast : Shahrukh Khan, Zayed Khan\nSinger : Sonu Nigam, Altaf Sabri, Hashim Sabri \nMusic Director : Anu Malik\nLyricst : Javed Akhtar\nMusic Label : T-Series',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mXkbWKr5ovU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/mXkbWKr5ovU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
# ...

# %%
type(item)
# Out:
# list

# %%
len(item)
# Out:
# 1

# %%
k = item[0].keys()
k
# Out:
# dict_keys(['kind', 'etag', 'id', 'snippet', 'statistics'])

# %%
item[0]['statistics']
# Out:
# {'viewCount': '127888097',
#  'likeCount': '947355',
#  'favoriteCount': '0',
#  'commentCount': '21475'}

# %%
url = 'https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=ATm0cWqowxE&key=AIzaSyC3EsHgVkGg11WfvEgVYuamubsGsjq1n-I&alt=json'
url
# Out:
# 'https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=ATm0cWqowxE&key=AIzaSyC3EsHgVkGg11WfvEgVYuamubsGsjq1n-I&alt=json'

# %%
import requests
import json

u = requests.get(url=url)
f = u.json()
f
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'Io-JP87-ZlV-0ZfPecjHEfGnDSo',
#  'nextPageToken': 'QURTSl9pM3VmcW1VbnpsVjVMcHNLbWdhU1FNZUhhZ2o0UVNFODRPT3M1clNCeWhzSWN2Wkt6bzA2WGx5bERZUHVaQ193Wk53ejIzTlZvNA==',
#  'pageInfo': {'totalResults': 19, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'mtHtyenFMHws3u231dr0iWQOU8w',
#    'id': 'UgzfuzpQyGc984ZGSId4AaABAg',
#    'snippet': {'videoId': 'ATm0cWqowxE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'tp4owXh774LttW63VVQYEu2ISD4',
#      'id': 'UgzfuzpQyGc984ZGSId4AaABAg',
#      'snippet': {'videoId': 'ATm0cWqowxE',
#       'textDisplay': 'Nice song',
#       'textOriginal': 'Nice song',
#       'authorDisplayName': 'rekha Chuhan',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSQuMQAXimkaYTR2XOBUNxj432_QSaed7n5wh9ENtPjM33Jc736PdxxqOtY6E_b=s48-c-k-c0x00ffffff-no-rj',
# ...

# %%
f.keys()
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'pageInfo', 'items'])

# %%
l = f['items']
l
# Out:
# [{'kind': 'youtube#commentThread',
#   'etag': 'mtHtyenFMHws3u231dr0iWQOU8w',
#   'id': 'UgzfuzpQyGc984ZGSId4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'tp4owXh774LttW63VVQYEu2ISD4',
#     'id': 'UgzfuzpQyGc984ZGSId4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'Nice song',
#      'textOriginal': 'Nice song',
#      'authorDisplayName': 'rekha Chuhan',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSQuMQAXimkaYTR2XOBUNxj432_QSaed7n5wh9ENtPjM33Jc736PdxxqOtY6E_b=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCwXa-QK5m3uVFGju_v1UluQ',
#      'authorChannelId': {'value': 'UCwXa-QK5m3uVFGju_v1UluQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-08T14:58:01Z',
#      'updatedAt': '2022-02-08T14:58:01Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
# ...

# %%
len(l)
# Out:
# 19

# %%
l[5]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'zWx-XHHDr6BXVB-7eHg0Idqq7Lk',
#  'id': 'UgyTDAnztueK6kLq6St4AaABAg',
#  'snippet': {'videoId': 'ATm0cWqowxE',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'EPs-865yjnmgSlHFUngunEtASc4',
#    'id': 'UgyTDAnztueK6kLq6St4AaABAg',
#    'snippet': {'videoId': 'ATm0cWqowxE',
#     'textDisplay': '🥺❤️🥰😍🖤💋',
#     'textOriginal': '🥺❤️🥰😍🖤💋',
#     'authorDisplayName': 'Karanjitsinh Zala',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQtv1M2Yu9JtniDzc-evrp7MvQEg51RIA2cWwCEqQKC9NHZnrj70eGy-9HFp4jp=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/channel/UCu8gFqKEpTGu0SlhTZQkDBw',
#     'authorChannelId': {'value': 'UCu8gFqKEpTGu0SlhTZQkDBw'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2022-02-08T13:19:50Z',
#     'updatedAt': '2022-02-08T13:19:50Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %%
com = l[5]['snippet']['topLevelComment']['snippet']['textOriginal']
com
# Out:
# '🥺❤️🥰😍🖤💋'

# %%
for i in l:
    print(i['snippet']['topLevelComment']['snippet']['textOriginal'])
# Out:
# Nice song
# Mood Off
# Guys mera gaming chaneel plz support
# https://youtube.com/channel/UCAoxvyQegnU0mb_Xiw1oXUw
# Guys mera gaming chaneel plz support
# https://youtube.com/channel/UCAoxvyQegnU0mb_Xiw1oXUw
# Guys mera gaming chaneel plz support
# https://youtube.com/channel/UCAoxvyQegnU0mb_Xiw1oXUw
# 🥺❤️🥰😍🖤💋
# I listen 2/3 times a day ......
# Night drive is the best feeling ever ❤️❤️
# Easy to start 💕😀
# Difficult to end💔 😭
# Your mother will be right soon, I will pray to Lord Buddha!
# May the good God bless u and your family ❣️
# nice song 💓💓💓💓💓💓
# U75O;L;
# Heart touching song❤❤❤❤
# vfbfjbf
# Nice song bro
# We all r pray save him
# 😋😋
# Get well soon

# %%
print(url)
# Out:
# https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=ATm0cWqowxE&key=AIzaSyC3EsHgVkGg11WfvEgVYuamubsGsjq1n-I&alt=json

# %%
for i in l:
    print(i)
    print()
# Out:
# {'kind': 'youtube#commentThread', 'etag': 'mtHtyenFMHws3u231dr0iWQOU8w', 'id': 'UgzfuzpQyGc984ZGSId4AaABAg', 'snippet': {'videoId': 'ATm0cWqowxE', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'tp4owXh774LttW63VVQYEu2ISD4', 'id': 'UgzfuzpQyGc984ZGSId4AaABAg', 'snippet': {'videoId': 'ATm0cWqowxE', 'textDisplay': 'Nice song', 'textOriginal': 'Nice song', 'authorDisplayName': 'rekha Chuhan', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSQuMQAXimkaYTR2XOBUNxj432_QSaed7n5wh9ENtPjM33Jc736PdxxqOtY6E_b=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCwXa-QK5m3uVFGju_v1UluQ', 'authorChannelId': {'value': 'UCwXa-QK5m3uVFGju_v1UluQ'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2022-02-08T14:58:01Z', 'updatedAt': '2022-02-08T14:58:01Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}
#
# ...

# %%
l[7].keys()
# Out:
# dict_keys(['kind', 'etag', 'id', 'snippet'])

# %%
rep = l[7]
rep
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'REoaifpSA2Vp44Y5Tt0HyDerdy0',
#  'id': 'Ugzlr_7-KLYHWYZQ89x4AaABAg',
#  'snippet': {'videoId': 'ATm0cWqowxE',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'vl8eqUcCNYaAs1g7BeLpUQ7x8mA',
#    'id': 'Ugzlr_7-KLYHWYZQ89x4AaABAg',
#    'snippet': {'videoId': 'ATm0cWqowxE',
#     'textDisplay': 'Night drive is the best feeling ever ❤️❤️',
#     'textOriginal': 'Night drive is the best feeling ever ❤️❤️',
#     'authorDisplayName': 'Technical Ansari',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQ4k375fNruEXXNI7WvpttmtGMKW2VxrbZM2-DM=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/channel/UCP3EaVgWMKzR_5HrcJila6g',
#     'authorChannelId': {'value': 'UCP3EaVgWMKzR_5HrcJila6g'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2022-02-08T12:13:53Z',
#     'updatedAt': '2022-02-08T12:13:53Z'}},
#   'canReply': True,
# ...
