# %%
url = 'https://www.instagram.com/imvickykumar999/?__a=1'
print(url)
# Out:
# https://www.instagram.com/imvickykumar999/?__a=1

# %%
import requests

# %%
r = requests.get(url)

# %%
import json
jar = json.loads(r.text)
jar
# Out:
# {'seo_category_infos': [['Beauty', 'beauty'],
#   ['Dance & Performance', 'dance_and_performance'],
#   ['Fitness', 'fitness'],
#   ['Food & Drink', 'food_and_drink'],
#   ['Home & Garden', 'home_and_garden'],
#   ['Music', 'music'],
#   ['Visual Arts', 'visual_arts']],
#  'logging_page_id': 'profilePage_7015147780',
#  'show_suggested_profiles': False,
#  'show_follow_dialog': False,
#  'graphql': {'user': {'biography': 'Hey Vicks 🍻\n🇮🇳 My Projects are my Imagination to turn into Reality.\n🎊 My Google Chat Bot coded in one night. ❤️\n😜👇',
#    'blocked_by_viewer': False,
#    'restricted_by_viewer': None,
#    'country_block': False,
#    'external_url': 'https://vixtest.herokuapp.com/',
#    'external_url_linkshimmed': 'https://l.instagram.com/?u=https%3A%2F%2Fvixtest.herokuapp.com%2F&e=ATMtB1PQmkQlx0uuxgJu7qHhAk0UaWATv3J2SU3XaNWlU7ZblIuAbRbFPCpBqzBtG9ze7sBJJJd6xeUD&s=1',
#    'edge_followed_by': {'count': 433},
#    'fbid': '17841407073406893',
#    'followed_by_viewer': False,
# ...

# %%
k =list(jar.keys())
k
# Out:
# ['seo_category_infos',
#  'logging_page_id',
#  'show_suggested_profiles',
#  'show_follow_dialog',
#  'graphql',
#  'toast_content_on_load',
#  'show_view_shop',
#  'profile_pic_edit_sync_props',
#  'always_show_message_button_to_pro_account']

# %%
r = jar['graphql']['user']
r
# Out:
# {'biography': 'Hey Vicks 🍻\n🇮🇳 My Projects are my Imagination to turn into Reality.\n🎊 My Google Chat Bot coded in one night. ❤️\n😜👇',
#  'blocked_by_viewer': False,
#  'restricted_by_viewer': None,
#  'country_block': False,
#  'external_url': 'https://vixtest.herokuapp.com/',
#  'external_url_linkshimmed': 'https://l.instagram.com/?u=https%3A%2F%2Fvixtest.herokuapp.com%2F&e=ATMtB1PQmkQlx0uuxgJu7qHhAk0UaWATv3J2SU3XaNWlU7ZblIuAbRbFPCpBqzBtG9ze7sBJJJd6xeUD&s=1',
#  'edge_followed_by': {'count': 433},
#  'fbid': '17841407073406893',
#  'followed_by_viewer': False,
#  'edge_follow': {'count': 884},
#  'follows_viewer': False,
#  'full_name': 'Vicky Kumar',
#  'has_ar_effects': False,
#  'has_clips': True,
#  'has_guides': False,
#  'has_channel': False,
#  'has_blocked_viewer': False,
#  'highlight_reel_count': 0,
#  'has_requested_viewer': False,
#  'hide_like_and_view_counts': False,
#  'id': '7015147780',
#  'is_business_account': False,
#  'is_professional_account': False,
# ...

# %%
r.keys()
# Out:
# dict_keys(['biography', 'blocked_by_viewer', 'restricted_by_viewer', 'country_block', 'external_url', 'external_url_linkshimmed', 'edge_followed_by', 'fbid', 'followed_by_viewer', 'edge_follow', 'follows_viewer', 'full_name', 'has_ar_effects', 'has_clips', 'has_guides', 'has_channel', 'has_blocked_viewer', 'highlight_reel_count', 'has_requested_viewer', 'hide_like_and_view_counts', 'id', 'is_business_account', 'is_professional_account', 'is_embeds_disabled', 'is_joined_recently', 'business_address_json', 'business_contact_method', 'business_email', 'business_phone_number', 'business_category_name', 'overall_category_name', 'category_enum', 'category_name', 'is_private', 'is_verified', 'edge_mutual_followed_by', 'profile_pic_url', 'profile_pic_url_hd', 'requested_by_viewer', 'should_show_category', 'should_show_public_contacts', 'username', 'connected_fb_page', 'pronouns', 'edge_felix_video_timeline', 'edge_owner_to_timeline_media', 'edge_saved_media', 'edge_media_collections', 'edge_
# ...

# %%
followers=r['edge_followed_by']
followers
# Out:
# {'count': 433}

# %%
following = r['edge_follow']
following
# Out:
# {'count': 884}

# %%
link = r['profile_pic_url_hd']
link
# Out:
# 'https://instagram.famd3-1.fna.fbcdn.net/v/t51.2885-19/s320x320/269751788_282087027280038_4779994421201724997_n.jpg?_nc_ht=instagram.famd3-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=j8CZDsYJ_aAAX8o8gAI&edm=ABfd0MgBAAAA&ccb=7-4&oh=00_AT8JYjD0JhOSYP7wBywsdlDo6BunJ1cqhUHO659Mu-xkeg&oe=6208CA9E&_nc_sid=7bff83'

# %%
url = ('https://www.googleapis.com/youtube/v3/videos?id=mXkbWKr5ovU&key=AIzaSyC3EsHgVkGg11WfvEgVYuamubsGsjq1n-I&part=snippet')
print(url)
# Out:
# https://www.googleapis.com/youtube/v3/videos?id=mXkbWKr5ovU&key=AIzaSyC3EsHgVkGg11WfvEgVYuamubsGsjq1n-I&part=snippet

# %%
import requests

# %%
f = requests.get(url)
f
# Out:
# <Response [200]>

# %%
url = ('https://www.googleapis.com/youtube/v3/videos?id=mXkbWKr5ovU&key=AIzaSyC3EsHgVkGg11WfvEgVYuamubsGsjq1n-I&part=statistics')
import requests
f=requests.get(url)
import json
pr = json.loads(f.text)
pr
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'SnMxz4m2vznfaMqYOO17i9WfGrM',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'yxDUK04TEvdXBehdaCKk4eMuopw',
#    'id': 'mXkbWKr5ovU',
#    'statistics': {'viewCount': '127864235',
#     'likeCount': '947069',
#     'favoriteCount': '0',
#     'commentCount': '21473'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
pr.keys()
# Out:
# dict_keys(['kind', 'etag', 'items', 'pageInfo'])

# %%
pr['items']
# Out:
# [{'kind': 'youtube#video',
#   'etag': 'yxDUK04TEvdXBehdaCKk4eMuopw',
#   'id': 'mXkbWKr5ovU',
#   'statistics': {'viewCount': '127864235',
#    'likeCount': '947069',
#    'favoriteCount': '0',
#    'commentCount': '21473'}}]

# %%
len('items')
# Out:
# 5

# %%
url = 'https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=mXkbWKr5ovU&key=AIzaSyC3EsHgVkGg11WfvEgVYuamubsGsjq1n-I&alt=json'
import requests
h=requests.get(url)
import json
pri = json.loads(h.text)
pri
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'wMsOAoU1AIsDDPRd0fRBqwrho5M',
#  'nextPageToken': 'QURTSl9pMzZWRFhvejJLWFRmWkthYm5jSVlMM05aQ205dTZ6SVFtanllVUhYSEtmbFZ5Y0tBSEVoblZWb3R3bzJjTXp2dVZrdFdib2dLYw==',
#  'pageInfo': {'totalResults': 19, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'e63nDzLAkLIqxEt_zkLYpI6LEDA',
#    'id': 'UgxqEBkbREa2xD0HNPd4AaABAg',
#    'snippet': {'videoId': 'mXkbWKr5ovU',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '9SpMXIV7LMvFj3N531y5hD94VMw',
#      'id': 'UgxqEBkbREa2xD0HNPd4AaABAg',
#      'snippet': {'videoId': 'mXkbWKr5ovU',
#       'textDisplay': 'Anyone still here in 2022🧐',
#       'textOriginal': 'Anyone still here in 2022🧐',
#       'authorDisplayName': 'ayush karn',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQdJFRI0_zWQpN0YBrg1X-zHwvvj1MjSk7fSgBZKGs=s48-c-k-c0x00ffffff-no-rj',
# ...

# %%
pri.keys()
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'pageInfo', 'items'])

# %%
pri['items']
# Out:
# [{'kind': 'youtube#commentThread',
#   'etag': 'e63nDzLAkLIqxEt_zkLYpI6LEDA',
#   'id': 'UgxqEBkbREa2xD0HNPd4AaABAg',
#   'snippet': {'videoId': 'mXkbWKr5ovU',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': '9SpMXIV7LMvFj3N531y5hD94VMw',
#     'id': 'UgxqEBkbREa2xD0HNPd4AaABAg',
#     'snippet': {'videoId': 'mXkbWKr5ovU',
#      'textDisplay': 'Anyone still here in 2022🧐',
#      'textOriginal': 'Anyone still here in 2022🧐',
#      'authorDisplayName': 'ayush karn',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQdJFRI0_zWQpN0YBrg1X-zHwvvj1MjSk7fSgBZKGs=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCfcRsIcwgiwwGgywmEC0kVQ',
#      'authorChannelId': {'value': 'UCfcRsIcwgiwwGgywmEC0kVQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-08T13:45:23Z',
#      'updatedAt': '2022-02-08T13:45:23Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
# ...

# %%
list(pri.keys())
# Out:
# ['kind', 'etag', 'nextPageToken', 'pageInfo', 'items']

# %%
r = len('items')
r
# Out:
# 5

# %%
t = pri['items']
t
# Out:
# [{'kind': 'youtube#commentThread',
#   'etag': 'C6PpZXds9cE2xNEtKTI-adSqv2Y',
#   'id': 'Ugz7kh9hJkSmT8hxU9R4AaABAg',
#   'snippet': {'videoId': 'mXkbWKr5ovU',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'iqn1uTRT6I2tBc6SQtG4EmWPIfQ',
#     'id': 'Ugz7kh9hJkSmT8hxU9R4AaABAg',
#     'snippet': {'videoId': 'mXkbWKr5ovU',
#      'textDisplay': 'Anuj - anupama waching this beautiful song',
#      'textOriginal': 'Anuj - anupama waching this beautiful song',
#      'authorDisplayName': 'muskan kumari -64',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRGmG_k_kxwDemU1FbrYLNHCS8KNYV0TKPMzi28CA=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCTuSOfPiQHPKCzimIxiuI3A',
#      'authorChannelId': {'value': 'UCTuSOfPiQHPKCzimIxiuI3A'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-08T10:07:11Z',
#      'updatedAt': '2022-02-08T10:07:11Z'}},
# ...

# %%
type(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 type(t)
#
# NameError: name 't' is not defined
